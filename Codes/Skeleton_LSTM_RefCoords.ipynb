# %%
import timeit
import scipy.io as sio
import scipy
import os
import random as rn
import numpy as np
from tensorflow import set_random_seed
import tensorflow as tf
os.environ['PYTHONHASHSEED'] = '0'
os.environ["CUDA_VISIBLE_DEVICES"]="-1"
rn.seed(123)
np.random.seed(123)
set_random_seed(123)
tf.set_random_seed(123)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
from keras import backend as K
K.set_session(sess)
import pandas as pd
from pathlib import Path
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.recurrent import LSTM
from keras.layers import Dense
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from keras.utils import to_categorical
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\hys19\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def import_skeleton_data(action, subject, trial):
    filename = f'Kinect2Dataset/Skeleton/a{action}_s{subject}_t{trial}_skeleton.mat'
    if Path(filename).is_file():
        mat = scipy.io.loadmat(filename)
        return mat['d_skel']
    else:
        return None

def transform_skeleton_data(action, subject, trial):
    matrices = []
    data = import_skeleton_data(action, subject, trial)
    if data is None: return None
    for frame in range(data.shape[2]):
        skelecton_joints = [i + 1 for i in range(20)]
        matrix = data[:,:,frame]
        matrix = np.insert(matrix, 0, skelecton_joints, axis=1)
        matrix = np.insert(matrix, 0, frame, axis=1)
        matrices.append(matrix)
    result = np.vstack(tuple(matrices))
    result = np.insert(result, 0, [[action], [subject], [trial]], axis=1)
    return result

def transform_skeleton_data_to_df(action, subject, trial):
    data = transform_skeleton_data(action, subject, trial)
    if data is None: return None
    df = pd.DataFrame(data)
    df.columns = ['action', 'subject', 'trial', 'frame', 'skeleton_joint', 'x', 'y', 'z']
    return df

# %%
# Read in all data
trial_end = 4
activity_end = 27
subject_end = 8

master_df = pd.DataFrame({'action': [], 'subject': [], 'trial': [], 'frame': [], 'skeleton_joint':[], 'x':[], 'y':[], 'z':[]})

for activity in range(1,activity_end+1):
    for subject in range(1,subject_end+1):  
        for trial in range(1,trial_end+1):
            temp_df = transform_skeleton_data_to_df(activity, subject, trial)
            master_df = pd.concat([master_df, temp_df])

# %%
# Transpose skeleton_joint column
for skeleton in list(master_df.skeleton_joint.unique()):
    temp_df_by_skel = master_df.loc[master_df['skeleton_joint'] == skeleton]
    temp_df_by_skel = temp_df_by_skel.rename(columns={'x': 'x'+str(int(skeleton)), 
                                                      'y': 'y'+str(int(skeleton)), 
                                                      'z': 'z'+str(int(skeleton))})
    temp_df_by_skel = temp_df_by_skel.drop(['skeleton_joint'], axis=1)
    if skeleton == 1.0:
        transformed = temp_df_by_skel
    else:
        transformed = transformed.merge(temp_df_by_skel, on=['action','subject','trial','frame'], how='left')
transformed = transformed.sort_values(by=['action','subject','trial','frame'])

# %%
# Compute position of joints relative to hip centre (no. 4)
# Normalize by the distance between hip centre and shoulder centre (no. 2)
transformed["dist_hip_shldr_ctr"] = np.sqrt( (transformed["x2"]-transformed["x4"])*(transformed["x2"]-transformed["x4"]) +
                                          (transformed["y2"]-transformed["y4"])*(transformed["y2"]-transformed["y4"]) +
                                          (transformed["z2"]-transformed["z4"])*(transformed["z2"]-transformed["z4"]) )
for joint in range(1,21):
    if joint == 4:
        continue
    transformed["x4.{0}".format(joint)] = (transformed["x{0}".format(joint)] - transformed["x4"])/transformed["dist_hip_shldr_ctr"]
    transformed["y4.{0}".format(joint)] = (transformed["y{0}".format(joint)] - transformed["y4"])/transformed["dist_hip_shldr_ctr"]
    transformed["z4.{0}".format(joint)] = (transformed["z{0}".format(joint)] - transformed["z4"])/transformed["dist_hip_shldr_ctr"]
    
for joint in range(1,21):
    transformed.drop("x{0}".format(joint), axis=1, inplace=True)
    transformed.drop("y{0}".format(joint), axis=1, inplace=True)
    transformed.drop("z{0}".format(joint), axis=1, inplace=True)
    
transformed.drop("dist_hip_shldr_ctr", axis=1, inplace=True)

# %%
# Prepare data for training: Zero padding to ensure sequences are of equal length, Data partition (70%-30%)
finalX = []
finaly = []
for activity in range(1,activity_end+1):
    for subject in range(1,subject_end+1):  
        for trial in range(1,trial_end+1):
            temp = transformed.loc[(transformed['action'] == activity) & 
                                   (transformed['subject'] == subject) &
                                   (transformed['trial'] == trial)]
            tempX = temp.filter(regex='[xyz].*')
            tempX = tempX.values
            tempy = temp['action'].values[0]
            finaly.append(tempy)
            npad = ((125-tempX.shape[0], 0), (0, 0))
            tempX = np.pad(tempX, pad_width=npad, mode='constant', constant_values=0)
            finalX.append(tempX)
            
finalX = np.stack(finalX)
finaly = np.stack(finaly)
finaly = to_categorical(finaly)

X_train, X_test, y_train, y_test = train_test_split(finalX, finaly, test_size=0.3, random_state=1)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((604, 125, 57), (260, 125, 57), (604, 28), (260, 28))

# %%
# LSTM
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(y_train.shape[1], activation='sigmoid'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 50)                21600
# _________________________________________________________________
# dense_1 (Dense)              (None, 28)                1428
# =================================================================
# Total params: 23,028
# Trainable params: 23,028
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Stop training when validation loss doesn't improve after 30 epochs
# Save the best model in terms of validation loss
earlyStopping = EarlyStopping(monitor='val_loss', patience=30, verbose=0, mode='min')
mcp_save = ModelCheckpoint('Skeleton model files/LSTM_skeleton_refcoords.hdf5', save_best_only=True, monitor='val_loss', mode='min')

# %%
start_time = timeit.default_timer()
LSTMRef_Hist = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10000, batch_size=32, callbacks=[earlyStopping, mcp_save])
elapsed = timeit.default_timer() - start_time
print("Time taken: " + str(elapsed) + "s")
model.load_weights('Skeleton model files/LSTM_skeleton_refcoords.hdf5')
# Out:
# Train on 604 samples, validate on 260 samples
# Epoch 1/10000
# 604/604 [==============================] - 3s 6ms/step - loss: 3.3261 - acc: 0.0464 - val_loss: 3.3140 - val_acc: 0.0462
# Epoch 2/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 3.2819 - acc: 0.0795 - val_loss: 3.2881 - val_acc: 0.0577
# Epoch 3/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 3.2070 - acc: 0.1093 - val_loss: 3.1523 - val_acc: 0.0731
# Epoch 4/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 3.0578 - acc: 0.0960 - val_loss: 3.0163 - val_acc: 0.1115
# Epoch 5/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 2.8917 - acc: 0.1722 - val_loss: 2.8535 - val_acc: 0.1423
# Epoch 6/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.7571 - acc: 0.1639 - val_loss: 2.7282 - val_acc: 0.1615
# Epoch 7/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.7083 - acc: 0.1523 - val_loss: 2.7103 - val_acc: 0.0885
# Epoch 8/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.6651 - acc: 0.1705 - val_loss: 2.6462 - val_acc: 0.1885
# Epoch 9/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.5598 - acc: 0.1904 - val_loss: 2.5679 - val_acc: 0.1654
# Epoch 10/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 2.5664 - acc: 0.1937 - val_loss: 2.5558 - val_acc: 0.1385
# Epoch 11/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 2.4938 - acc: 0.2103 - val_loss: 2.4805 - val_acc: 0.1538
# Epoch 12/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 2.3955 - acc: 0.2268 - val_loss: 2.3937 - val_acc: 0.1885
# Epoch 13/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 2.2810 - acc: 0.2533 - val_loss: 2.3023 - val_acc: 0.2192
# Epoch 14/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.2205 - acc: 0.2417 - val_loss: 2.3050 - val_acc: 0.1808
# Epoch 15/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.1799 - acc: 0.2483 - val_loss: 2.1798 - val_acc: 0.2115
# Epoch 16/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 2.0424 - acc: 0.3096 - val_loss: 2.0681 - val_acc: 0.2885
# Epoch 17/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.9359 - acc: 0.3460 - val_loss: 1.9825 - val_acc: 0.2577
# Epoch 18/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 1.9033 - acc: 0.3361 - val_loss: 1.9286 - val_acc: 0.2846
# Epoch 19/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.8017 - acc: 0.3642 - val_loss: 1.8287 - val_acc: 0.3269
# Epoch 20/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.8053 - acc: 0.3543 - val_loss: 1.9418 - val_acc: 0.2885
# Epoch 21/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.7540 - acc: 0.3576 - val_loss: 1.7600 - val_acc: 0.3192
# Epoch 22/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.6166 - acc: 0.4222 - val_loss: 1.6762 - val_acc: 0.3346
# Epoch 23/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.5689 - acc: 0.4255 - val_loss: 1.6315 - val_acc: 0.3538
# Epoch 24/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.4947 - acc: 0.4818 - val_loss: 1.5941 - val_acc: 0.4154
# Epoch 25/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.4784 - acc: 0.4967 - val_loss: 1.5885 - val_acc: 0.4192
# Epoch 26/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.4658 - acc: 0.4983 - val_loss: 1.5439 - val_acc: 0.4577
# Epoch 27/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.4249 - acc: 0.5430 - val_loss: 1.4763 - val_acc: 0.4538
# Epoch 28/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.4054 - acc: 0.5497 - val_loss: 1.5174 - val_acc: 0.4692
# Epoch 29/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 1.3127 - acc: 0.5911 - val_loss: 1.4676 - val_acc: 0.5038
# Epoch 30/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.3246 - acc: 0.5811 - val_loss: 1.4118 - val_acc: 0.4885
# Epoch 31/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 1.2871 - acc: 0.5480 - val_loss: 1.4389 - val_acc: 0.4769
# Epoch 32/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.3019 - acc: 0.5712 - val_loss: 1.3484 - val_acc: 0.5000
# Epoch 33/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.2343 - acc: 0.5911 - val_loss: 1.3177 - val_acc: 0.5385
# Epoch 34/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.4306 - acc: 0.5232 - val_loss: 1.4992 - val_acc: 0.4692
# Epoch 35/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.3744 - acc: 0.5248 - val_loss: 1.3786 - val_acc: 0.5192
# Epoch 36/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.2527 - acc: 0.6076 - val_loss: 1.2734 - val_acc: 0.5577
# Epoch 37/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 1.1494 - acc: 0.6275 - val_loss: 1.2454 - val_acc: 0.5885
# Epoch 38/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 1.0929 - acc: 0.6540 - val_loss: 1.2275 - val_acc: 0.5615
# Epoch 39/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.0622 - acc: 0.6507 - val_loss: 1.1602 - val_acc: 0.5808
# Epoch 40/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 1.0023 - acc: 0.6805 - val_loss: 1.0818 - val_acc: 0.6615
# Epoch 41/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.9590 - acc: 0.7003 - val_loss: 1.0371 - val_acc: 0.6500
# Epoch 42/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.9435 - acc: 0.7136 - val_loss: 1.0447 - val_acc: 0.6500
# Epoch 43/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.9095 - acc: 0.7152 - val_loss: 1.0540 - val_acc: 0.6692
# Epoch 44/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.9850 - acc: 0.6606 - val_loss: 1.1405 - val_acc: 0.6038
# Epoch 45/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.9609 - acc: 0.6705 - val_loss: 1.0812 - val_acc: 0.6500
# Epoch 46/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.8894 - acc: 0.7169 - val_loss: 0.9852 - val_acc: 0.6538
# Epoch 47/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.8455 - acc: 0.7086 - val_loss: 0.9756 - val_acc: 0.6885
# Epoch 48/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.8319 - acc: 0.7334 - val_loss: 0.9789 - val_acc: 0.6885
# Epoch 49/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.8296 - acc: 0.7152 - val_loss: 1.0328 - val_acc: 0.6500
# Epoch 50/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.8295 - acc: 0.7086 - val_loss: 0.9515 - val_acc: 0.6692
# Epoch 51/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.7564 - acc: 0.7781 - val_loss: 0.8651 - val_acc: 0.7231
# Epoch 52/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.7202 - acc: 0.7947 - val_loss: 0.8512 - val_acc: 0.7192
# Epoch 53/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.6909 - acc: 0.8063 - val_loss: 0.8098 - val_acc: 0.7423
# Epoch 54/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.7028 - acc: 0.8046 - val_loss: 0.8250 - val_acc: 0.7231
# Epoch 55/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.6746 - acc: 0.7881 - val_loss: 0.7792 - val_acc: 0.7538
# Epoch 56/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.6611 - acc: 0.8063 - val_loss: 0.8126 - val_acc: 0.7308
# Epoch 57/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.6544 - acc: 0.7997 - val_loss: 0.7511 - val_acc: 0.7615
# Epoch 58/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.6195 - acc: 0.8262 - val_loss: 0.7267 - val_acc: 0.7577
# Epoch 59/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.5604 - acc: 0.8477 - val_loss: 0.6921 - val_acc: 0.7769
# Epoch 60/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.5425 - acc: 0.8576 - val_loss: 0.6902 - val_acc: 0.7846
# Epoch 61/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.5389 - acc: 0.8526 - val_loss: 0.6559 - val_acc: 0.8154
# Epoch 62/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5100 - acc: 0.8742 - val_loss: 0.6465 - val_acc: 0.7923
# Epoch 63/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.4962 - acc: 0.8659 - val_loss: 0.6649 - val_acc: 0.7769
# Epoch 64/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.4968 - acc: 0.8675 - val_loss: 0.6329 - val_acc: 0.8231
# Epoch 65/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.4935 - acc: 0.8460 - val_loss: 0.6956 - val_acc: 0.8000
# Epoch 66/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.5874 - acc: 0.8295 - val_loss: 0.7690 - val_acc: 0.7615
# Epoch 67/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.5471 - acc: 0.8295 - val_loss: 0.7217 - val_acc: 0.8038
# Epoch 68/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5367 - acc: 0.8295 - val_loss: 0.6227 - val_acc: 0.8346
# Epoch 69/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.5309 - acc: 0.8411 - val_loss: 0.6258 - val_acc: 0.8115
# Epoch 70/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.4662 - acc: 0.8709 - val_loss: 0.5417 - val_acc: 0.8615
# Epoch 71/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.4438 - acc: 0.8758 - val_loss: 0.5667 - val_acc: 0.8192
# Epoch 72/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.4163 - acc: 0.8775 - val_loss: 0.5412 - val_acc: 0.8385
# Epoch 73/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.4039 - acc: 0.8758 - val_loss: 0.4999 - val_acc: 0.8346
# Epoch 74/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3830 - acc: 0.8825 - val_loss: 0.4902 - val_acc: 0.8346
# Epoch 75/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3764 - acc: 0.8725 - val_loss: 0.4797 - val_acc: 0.8731
# Epoch 76/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3641 - acc: 0.9040 - val_loss: 0.4406 - val_acc: 0.8692
# Epoch 77/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3427 - acc: 0.9172 - val_loss: 0.4947 - val_acc: 0.8808
# Epoch 78/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3619 - acc: 0.9089 - val_loss: 0.4815 - val_acc: 0.8769
# Epoch 79/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3381 - acc: 0.9222 - val_loss: 0.4628 - val_acc: 0.8615
# Epoch 80/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3633 - acc: 0.8891 - val_loss: 0.4472 - val_acc: 0.8808
# Epoch 81/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3313 - acc: 0.9056 - val_loss: 0.4865 - val_acc: 0.8692
# Epoch 82/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.3311 - acc: 0.9073 - val_loss: 0.4518 - val_acc: 0.8962
# Epoch 83/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.3458 - acc: 0.9156 - val_loss: 0.4561 - val_acc: 0.8615
# Epoch 84/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2963 - acc: 0.9222 - val_loss: 0.5277 - val_acc: 0.8115
# Epoch 85/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2967 - acc: 0.9073 - val_loss: 0.4251 - val_acc: 0.8654
# Epoch 86/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.4025 - acc: 0.8742 - val_loss: 0.5379 - val_acc: 0.8385
# Epoch 87/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3417 - acc: 0.8974 - val_loss: 0.4706 - val_acc: 0.8577
# Epoch 88/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.2974 - acc: 0.9089 - val_loss: 0.4414 - val_acc: 0.8731
# Epoch 89/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.2918 - acc: 0.9139 - val_loss: 0.5405 - val_acc: 0.8500
# Epoch 90/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3352 - acc: 0.9089 - val_loss: 0.4202 - val_acc: 0.8846
# Epoch 91/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3476 - acc: 0.9056 - val_loss: 0.4583 - val_acc: 0.8538
# Epoch 92/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3149 - acc: 0.9172 - val_loss: 0.3988 - val_acc: 0.8692
# Epoch 93/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2621 - acc: 0.9238 - val_loss: 0.3792 - val_acc: 0.8923
# Epoch 94/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2626 - acc: 0.9305 - val_loss: 0.3972 - val_acc: 0.8731
# Epoch 95/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2526 - acc: 0.9272 - val_loss: 0.3760 - val_acc: 0.9038
# Epoch 96/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2435 - acc: 0.9387 - val_loss: 0.3820 - val_acc: 0.8923
# Epoch 97/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2688 - acc: 0.9238 - val_loss: 0.4111 - val_acc: 0.8615
# Epoch 98/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2719 - acc: 0.9073 - val_loss: 0.3675 - val_acc: 0.8885
# Epoch 99/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2684 - acc: 0.9172 - val_loss: 0.3497 - val_acc: 0.9115
# Epoch 100/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2022 - acc: 0.9470 - val_loss: 0.3423 - val_acc: 0.9038
# Epoch 101/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1950 - acc: 0.9437 - val_loss: 0.2860 - val_acc: 0.9269
# Epoch 102/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2317 - acc: 0.9338 - val_loss: 0.3502 - val_acc: 0.8846
# Epoch 103/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2387 - acc: 0.9172 - val_loss: 0.4153 - val_acc: 0.8192
# Epoch 104/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2389 - acc: 0.9222 - val_loss: 0.3089 - val_acc: 0.9269
# Epoch 105/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2084 - acc: 0.9454 - val_loss: 0.4293 - val_acc: 0.8769
# Epoch 106/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2960 - acc: 0.9123 - val_loss: 0.6923 - val_acc: 0.7692
# Epoch 107/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.5035 - acc: 0.8427 - val_loss: 0.5271 - val_acc: 0.8769
# Epoch 108/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.3412 - acc: 0.9089 - val_loss: 0.4545 - val_acc: 0.8846
# Epoch 109/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.3096 - acc: 0.9073 - val_loss: 0.5105 - val_acc: 0.8192
# Epoch 110/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2536 - acc: 0.9255 - val_loss: 0.3228 - val_acc: 0.9115
# Epoch 111/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2759 - acc: 0.9172 - val_loss: 0.3045 - val_acc: 0.9077
# Epoch 112/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2230 - acc: 0.9288 - val_loss: 0.5221 - val_acc: 0.8231
# Epoch 113/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2555 - acc: 0.9321 - val_loss: 0.3024 - val_acc: 0.9192
# Epoch 114/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2485 - acc: 0.9205 - val_loss: 0.3314 - val_acc: 0.9154
# Epoch 115/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1908 - acc: 0.9470 - val_loss: 0.3181 - val_acc: 0.9038
# Epoch 116/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1554 - acc: 0.9570 - val_loss: 0.2707 - val_acc: 0.9077
# Epoch 117/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1571 - acc: 0.9603 - val_loss: 0.2494 - val_acc: 0.9385
# Epoch 118/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1748 - acc: 0.9487 - val_loss: 0.2549 - val_acc: 0.9308
# Epoch 119/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1555 - acc: 0.9570 - val_loss: 0.2461 - val_acc: 0.9346
# Epoch 120/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1539 - acc: 0.9553 - val_loss: 0.2568 - val_acc: 0.9231
# Epoch 121/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1559 - acc: 0.9437 - val_loss: 0.2536 - val_acc: 0.9231
# Epoch 122/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1554 - acc: 0.9503 - val_loss: 0.2300 - val_acc: 0.9500
# Epoch 123/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1175 - acc: 0.9702 - val_loss: 0.2295 - val_acc: 0.9346
# Epoch 124/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1439 - acc: 0.9702 - val_loss: 0.2350 - val_acc: 0.9462
# Epoch 125/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1601 - acc: 0.9553 - val_loss: 0.2618 - val_acc: 0.9346
# Epoch 126/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2734 - acc: 0.9172 - val_loss: 0.4644 - val_acc: 0.8654
# Epoch 127/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.3367 - acc: 0.9023 - val_loss: 0.4062 - val_acc: 0.8769
# Epoch 128/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2872 - acc: 0.9255 - val_loss: 0.4355 - val_acc: 0.8769
# Epoch 129/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2544 - acc: 0.9305 - val_loss: 0.2549 - val_acc: 0.9385
# Epoch 130/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1770 - acc: 0.9503 - val_loss: 0.2324 - val_acc: 0.9308
# Epoch 131/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1736 - acc: 0.9536 - val_loss: 0.2231 - val_acc: 0.9385
# Epoch 132/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2407 - acc: 0.9123 - val_loss: 0.3256 - val_acc: 0.8962
# Epoch 133/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1759 - acc: 0.9421 - val_loss: 0.2778 - val_acc: 0.8923
# Epoch 134/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1572 - acc: 0.9520 - val_loss: 0.2408 - val_acc: 0.9462
# Epoch 135/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1376 - acc: 0.9702 - val_loss: 0.2350 - val_acc: 0.9385
# Epoch 136/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1430 - acc: 0.9619 - val_loss: 0.2314 - val_acc: 0.9615
# Epoch 137/10000
# 604/604 [==============================] - 3s 5ms/step - loss: 0.1156 - acc: 0.9801 - val_loss: 0.2175 - val_acc: 0.9385
# Epoch 138/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1167 - acc: 0.9735 - val_loss: 0.1999 - val_acc: 0.9538
# Epoch 139/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1080 - acc: 0.9785 - val_loss: 0.2121 - val_acc: 0.9462
# Epoch 140/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1024 - acc: 0.9818 - val_loss: 0.1841 - val_acc: 0.9462
# Epoch 141/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1084 - acc: 0.9752 - val_loss: 0.1930 - val_acc: 0.9462
# Epoch 142/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0924 - acc: 0.9851 - val_loss: 0.1615 - val_acc: 0.9500
# Epoch 143/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.0881 - acc: 0.9884 - val_loss: 0.1770 - val_acc: 0.9577
# Epoch 144/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.0828 - acc: 0.9834 - val_loss: 0.1862 - val_acc: 0.9577
# Epoch 145/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.0786 - acc: 0.9868 - val_loss: 0.1891 - val_acc: 0.9577
# Epoch 146/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.0730 - acc: 0.9884 - val_loss: 0.1824 - val_acc: 0.9538
# Epoch 147/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.0797 - acc: 0.9834 - val_loss: 0.1845 - val_acc: 0.9462
# Epoch 148/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1031 - acc: 0.9719 - val_loss: 0.2272 - val_acc: 0.9192
# Epoch 149/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1955 - acc: 0.9354 - val_loss: 0.2712 - val_acc: 0.9077
# Epoch 150/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.2772 - acc: 0.9156 - val_loss: 0.4670 - val_acc: 0.8423
# Epoch 151/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2110 - acc: 0.9305 - val_loss: 0.3566 - val_acc: 0.8885
# Epoch 152/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2692 - acc: 0.9089 - val_loss: 0.8103 - val_acc: 0.6962
# Epoch 153/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.6148 - acc: 0.7964 - val_loss: 0.5238 - val_acc: 0.8115
# Epoch 154/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.3843 - acc: 0.8825 - val_loss: 0.5614 - val_acc: 0.8500
# Epoch 155/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.3709 - acc: 0.8957 - val_loss: 0.4783 - val_acc: 0.8500
# Epoch 156/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2618 - acc: 0.9156 - val_loss: 0.3955 - val_acc: 0.8692
# Epoch 157/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2169 - acc: 0.9421 - val_loss: 0.2675 - val_acc: 0.9308
# Epoch 158/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1567 - acc: 0.9570 - val_loss: 0.2120 - val_acc: 0.9423
# Epoch 159/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1551 - acc: 0.9553 - val_loss: 0.2655 - val_acc: 0.9346
# Epoch 160/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1461 - acc: 0.9619 - val_loss: 0.2375 - val_acc: 0.9115
# Epoch 161/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1171 - acc: 0.9752 - val_loss: 0.1705 - val_acc: 0.9577
# Epoch 162/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0833 - acc: 0.9868 - val_loss: 0.1634 - val_acc: 0.9577
# Epoch 163/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1126 - acc: 0.9752 - val_loss: 0.2709 - val_acc: 0.9423
# Epoch 164/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1442 - acc: 0.9553 - val_loss: 0.2203 - val_acc: 0.9346
# Epoch 165/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1140 - acc: 0.9768 - val_loss: 0.2178 - val_acc: 0.9500
# Epoch 166/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1073 - acc: 0.9785 - val_loss: 0.2165 - val_acc: 0.9385
# Epoch 167/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1139 - acc: 0.9785 - val_loss: 0.2390 - val_acc: 0.9231
# Epoch 168/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0989 - acc: 0.9801 - val_loss: 0.1559 - val_acc: 0.9692
# Epoch 169/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0777 - acc: 0.9868 - val_loss: 0.1330 - val_acc: 0.9654
# Epoch 170/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0729 - acc: 0.9851 - val_loss: 0.1661 - val_acc: 0.9423
# Epoch 171/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0828 - acc: 0.9768 - val_loss: 0.1973 - val_acc: 0.9346
# Epoch 172/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0694 - acc: 0.9901 - val_loss: 0.1551 - val_acc: 0.9538
# Epoch 173/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0923 - acc: 0.9735 - val_loss: 0.1882 - val_acc: 0.9462
# Epoch 174/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1483 - acc: 0.9520 - val_loss: 0.2603 - val_acc: 0.9385
# Epoch 175/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1098 - acc: 0.9768 - val_loss: 0.2906 - val_acc: 0.9038
# Epoch 176/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1080 - acc: 0.9768 - val_loss: 0.1776 - val_acc: 0.9538
# Epoch 177/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0914 - acc: 0.9768 - val_loss: 0.1656 - val_acc: 0.9654
# Epoch 178/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0614 - acc: 0.9901 - val_loss: 0.1660 - val_acc: 0.9423
# Epoch 179/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0628 - acc: 0.9884 - val_loss: 0.2001 - val_acc: 0.9462
# Epoch 180/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0532 - acc: 0.9917 - val_loss: 0.1268 - val_acc: 0.9769
# Epoch 181/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0501 - acc: 0.9884 - val_loss: 0.1303 - val_acc: 0.9731
# Epoch 182/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0469 - acc: 0.9950 - val_loss: 0.1289 - val_acc: 0.9769
# Epoch 183/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0518 - acc: 0.9884 - val_loss: 0.1367 - val_acc: 0.9692
# Epoch 184/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0541 - acc: 0.9868 - val_loss: 0.1359 - val_acc: 0.9654
# Epoch 185/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0503 - acc: 0.9917 - val_loss: 0.1172 - val_acc: 0.9731
# Epoch 186/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0406 - acc: 0.9917 - val_loss: 0.1197 - val_acc: 0.9692
# Epoch 187/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0396 - acc: 0.9934 - val_loss: 0.1119 - val_acc: 0.9769
# Epoch 188/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0345 - acc: 0.9967 - val_loss: 0.1133 - val_acc: 0.9731
# Epoch 189/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0344 - acc: 0.9967 - val_loss: 0.1219 - val_acc: 0.9769
# Epoch 190/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0442 - acc: 0.9917 - val_loss: 0.1070 - val_acc: 0.9731
# Epoch 191/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0356 - acc: 0.9950 - val_loss: 0.1099 - val_acc: 0.9769
# Epoch 192/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0304 - acc: 0.9967 - val_loss: 0.1153 - val_acc: 0.9731
# Epoch 193/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0327 - acc: 0.9950 - val_loss: 0.1168 - val_acc: 0.9731
# Epoch 194/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0527 - acc: 0.9884 - val_loss: 0.1313 - val_acc: 0.9692
# Epoch 195/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0373 - acc: 0.9917 - val_loss: 0.1222 - val_acc: 0.9808
# Epoch 196/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0377 - acc: 0.9934 - val_loss: 0.2044 - val_acc: 0.9423
# Epoch 197/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0511 - acc: 0.9868 - val_loss: 0.1396 - val_acc: 0.9654
# Epoch 198/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0330 - acc: 0.9983 - val_loss: 0.1366 - val_acc: 0.9731
# Epoch 199/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0288 - acc: 0.9983 - val_loss: 0.1275 - val_acc: 0.9731
# Epoch 200/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0455 - acc: 0.9884 - val_loss: 0.1845 - val_acc: 0.9462
# Epoch 201/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1097 - acc: 0.9636 - val_loss: 0.2573 - val_acc: 0.9269
# Epoch 202/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1292 - acc: 0.9586 - val_loss: 0.2228 - val_acc: 0.9500
# Epoch 203/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0781 - acc: 0.9834 - val_loss: 0.2030 - val_acc: 0.9462
# Epoch 204/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0444 - acc: 0.9950 - val_loss: 0.1291 - val_acc: 0.9692
# Epoch 205/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.0406 - acc: 0.9934 - val_loss: 0.1223 - val_acc: 0.9731
# Epoch 206/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0339 - acc: 0.9950 - val_loss: 0.1361 - val_acc: 0.9692
# Epoch 207/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0300 - acc: 0.9983 - val_loss: 0.1239 - val_acc: 0.9731
# Epoch 208/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0397 - acc: 0.9917 - val_loss: 0.1491 - val_acc: 0.9654
# Epoch 209/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0664 - acc: 0.9801 - val_loss: 0.2824 - val_acc: 0.9115
# Epoch 210/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1201 - acc: 0.9669 - val_loss: 0.2291 - val_acc: 0.9462
# Epoch 211/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0855 - acc: 0.9768 - val_loss: 0.2267 - val_acc: 0.9462
# Epoch 212/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2837 - acc: 0.9172 - val_loss: 0.3667 - val_acc: 0.8846
# Epoch 213/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2700 - acc: 0.9123 - val_loss: 0.3189 - val_acc: 0.9154
# Epoch 214/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.2172 - acc: 0.9454 - val_loss: 0.3830 - val_acc: 0.8615
# Epoch 215/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1768 - acc: 0.9404 - val_loss: 0.2530 - val_acc: 0.9231
# Epoch 216/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1465 - acc: 0.9553 - val_loss: 0.1943 - val_acc: 0.9385
# Epoch 217/10000
# 604/604 [==============================] - 3s 4ms/step - loss: 0.1170 - acc: 0.9586 - val_loss: 0.2184 - val_acc: 0.9269
# Epoch 218/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1137 - acc: 0.9652 - val_loss: 0.2216 - val_acc: 0.9308
# Epoch 219/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.1015 - acc: 0.9785 - val_loss: 0.1486 - val_acc: 0.9615
# Epoch 220/10000
# 604/604 [==============================] - 2s 4ms/step - loss: 0.0655 - acc: 0.9884 - val_loss: 0.1652 - val_acc: 0.9577
# Time taken: 556.7151854906066s

# %%
scores = model.evaluate(X_train, y_train, verbose=0)
print("Train Accuracy: %.2f%%" % (scores[1]*100))
scores = model.evaluate(X_test, y_test, verbose=0)
print("Test Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Train Accuracy: 99.50%
# Test Accuracy: 97.31%

# %%
predictions = model.predict(X_test)
target_names = ['Swipe Left', 'Swipe Right', 'Wave', 'Clap', 'Throw', 'Arm Cross', 'Basketball Shoot', 
                'Draw X', 'Draw Circle (CW)', 'Draw Circle (CCW)', 'Draw Triangle', 'Bowling', 'Boxing', 
                'Baseball Swing', 'Tennis Swing', 'Arm Curl', 'Tennis Serve', 'Push', 'Knock', 'Catch',
                'Pickup and Throw', 'Jog', 'Walk', 'Sit to Stand', 'Stand to Sit', 'Lunge', 'Squat']
print(classification_report(y_test.argmax(axis=1), predictions.argmax(axis=1), target_names=target_names))
# Out:
#                    precision    recall  f1-score   support
#
#        Swipe Left       1.00      1.00      1.00         8
#       Swipe Right       1.00      0.91      0.95        11
#              Wave       1.00      0.92      0.96        12
#              Clap       1.00      0.92      0.96        12
#             Throw       1.00      1.00      1.00         6
#         Arm Cross       1.00      1.00      1.00         8
#  Basketball Shoot       1.00      1.00      1.00         9
#            Draw X       1.00      1.00      1.00        12
#  Draw Circle (CW)       0.89      1.00      0.94         8
# Draw Circle (CCW)       0.83      1.00      0.91        10
#     Draw Triangle       1.00      0.62      0.77         8
#           Bowling       1.00      1.00      1.00         9
#            Boxing       1.00      1.00      1.00         8
#    Baseball Swing       1.00      1.00      1.00        11
#      Tennis Swing       1.00      1.00      1.00         5
#          Arm Curl       0.93      1.00      0.96        13
#      Tennis Serve       1.00      1.00      1.00         9
#              Push       1.00      1.00      1.00        11
#             Knock       0.88      1.00      0.94        15
#             Catch       1.00      1.00      1.00        10
#  Pickup and Throw       1.00      1.00      1.00         7
#               Jog       0.90      1.00      0.95         9
#              Walk       1.00      0.92      0.96        13
#      Sit to Stand       1.00      1.00      1.00         7
#      Stand to Sit       1.00      1.00      1.00         8
#             Lunge       1.00      1.00      1.00         8
#             Squat       1.00      1.00      1.00        13
#
#         micro avg       0.97      0.97      0.97       260
#         macro avg       0.98      0.97      0.97       260
#      weighted avg       0.98      0.97      0.97       260

# %%
#from keras.models import load_model
#model = load_model('LSTM_skeleton_refcoords.hdf5')

# %%
with open('Skeleton model files/LSTMRef_Hist', 'wb') as file:
    pickle.dump(LSTMRef_Hist.history, file)

# %%
# summarize history for accuracy
plt.plot(LSTMRef_Hist.history['acc'])
plt.plot(LSTMRef_Hist.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(LSTMRef_Hist.history['loss'])
plt.plot(LSTMRef_Hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
